# %% [markdown]
# ## 1. Importing necessary modules

# %%
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. Loading dataset using pandas

# %%
# Load datasets
train_df = pd.read_csv(r"F:\final year project\HAR DATASET\train.csv")
test_df = pd.read_csv(r"F:\final year project\HAR DATASET\test.csv")

# %% [markdown]
# ### 2.1. Getting the head of data

# %%
train_df.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %%
test_df.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
# 1           0.286027          -0.013163          -0.119083         -0.975415
# 2           0.275485          -0.026050          -0.118152         -0.993819
# 3           0.270298          -0.032614          -0.117520         -0.994743
# 4           0.274833          -0.027848          -0.129527         -0.993852
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
# 1         -0.967458         -0.944958         -0.986799         -0.968401
# 2         -0.969926         -0.962748         -0.994403         -0.970735
# 3         -0.973268         -0.967091         -0.995274         -0.974471
# 4         -0.967445         -0.978295         -0.994111         -0.965953
#
# ...

# %% [markdown]
# ### 2.2. Changing columns name

# %%
columns = train_df.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train_df.columns = columns
test_df.columns = columns

test_df.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'fBodyBodyGyroJerkMagkurtosis', 'angletBodyAccMeangravity',
#        'angletBodyAccJerkMeangravityMean', 'angletBodyGyroMeangravityMean',
#        'angletBodyGyroJerkMeangravityMean', 'angleXgravityMean',
#        'angleYgravityMean', 'angleZgravityMean', 'subject', 'Activity'],
#       dtype='object', length=563)

# %% [markdown]
# ## 3. Data Preprocessing

# %%
print('Number of duplicates in train : ',sum(train_df.duplicated()))
print('Number of duplicates in test : ', sum(test_df.duplicated()))
# Out:
# Number of duplicates in train :  0
# Number of duplicates in test :  0

# %% [markdown]
# ### 3.1 Checking for missing values

# %%
print('Total number of missing values in train : ', train_df.isna().values.sum())
print('Total number of missing values in train : ', test_df.isna().values.sum())
# Out:
# Total number of missing values in train :  0
# Total number of missing values in train :  0

# %% [markdown]
# ### 3.2 Checking for class imbalance

# %%
plt.figure(figsize=(10,8))
plt.title('Barplot of Activity')
sns.countplot(train_df.Activity)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text major ticklabel objects>)

# %% [markdown]
# ### Observation - There is almost same number of observations across all the six activities so this data does not have class imbalance problem.

# %% [markdown]
# ## 4. Exploratory Data Analysis
# ### Based on the common nature of activities we can broadly put them in two categories.
#
# ### Static and dynamic activities :
# ### SITTING, STANDING, LAYING can be considered as static activities with no motion involved
# ### WALKING, WALKING_DOWNSTAIRS, WALKING_UPSTAIRS can be considered as dynamic activities with significant amount of motion involved
# ### Let's consider tBodyAccMag-mean() feature to differentiate among these two broader set of activities.
#
# ### If we try to build a simple classification model to classify the activity using one variable at a time then probability density function(PDF) is very helpful to assess importance of a continuous variable.

# %% [markdown]
# ### 4.1 Analysing tBodyAccMagmean feature

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train_df, hue='Activity', size=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()
# Out:
# C:\Users\Pooja\anaconda3\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### 4.2 Magnitude of an acceleration can saperate it well

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='Activity', y='tBodyAccMagmean',data=train_df, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Observations:
#
# ### If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# ### If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# ### If tAccMean > 0.0 then the Activity is WalkingDownstairs.
# ### We can classify 75% the Acitivity labels with some errors.

# %% [markdown]
# ### 4.3 Position of GravityAccelerationComponants also matters

# %%
sns.boxplot(x='Activity', y='angleXgravityMean', data=train_df)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# ### Observations:
#
# ### If angleX,gravityMean > 0 then Activity is Laying.
# ### We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %% [markdown]
# ### 4.4 Analysing Angle between Y-axis and gravityMean feature¶

# %%
sns.boxplot(x='Activity', y='angleYgravityMean', data = train_df, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# ### Similarly, using Angle between Y-axis and gravityMean we can seperate LAYING from other activities but again it leads to some misclassification error.

# %% [markdown]
# ## 5. Visualizing data using T-sne

# %% [markdown]
# ### Using t-SNE data can be visualized from a extremely high dimensional space to a low dimensional space and still it retains lots of actual information. Given training data has 561 unqiue features, using t-SNE let's visualize it to a 2D space.

# %%
from sklearn.manifold import TSNE

# %%
X_for_tsne = train_df.drop(['subject', 'Activity'], axis=1)

# %%
# %time
tsne = TSNE(random_state = 42, n_components=2, verbose=1, perplexity=50, n_iter=1000).fit_transform(X_for_tsne)
# Out:
# Wall time: 0 ns
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 1.426s...
# [t-SNE] Computed neighbors for 7352 samples in 49.943s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.125954
# [t-SNE] KL divergence after 1000 iterations: 1.282853

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x =tsne[:, 0], y = tsne[:, 1], hue = train_df["Activity"],palette="bright")

# %% [markdown]
# ### Using the two new components obtained through t-SNE we can visualize and seperate all the six activities in a 2D space.

# %% [markdown]
# ## 6. Machine Learning Model

# %%
X_train = train_df.drop(['subject', 'Activity'], axis=1)
y_train = train_df.Activity
X_test = test_df.drop(['subject', 'Activity'], axis=1)
y_test = test_df.Activity
print('Training data size : ', X_train.shape)
print('Test data size : ', X_test.shape)
# Out:
# Training data size :  (7352, 561)
# Test data size :  (2947, 561)

# %% [markdown]
# ### 6.1 Logistic regression model with Hyperparameter tuning and cross validation

# %%
from sklearn. linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

import warnings
warnings.filterwarnings("ignore")

# %%
parameters = {'C':np.arange(10,61,10), 'penalty':['l2','l1']}
lr_classifier = LogisticRegression()
lr_classifier_rs = RandomizedSearchCV(lr_classifier, param_distributions=parameters, cv=5,random_state = 42)
lr_classifier_rs.fit(X_train, y_train)
y_pred = lr_classifier_rs.predict(X_test)

# %%
lr_accuracy = accuracy_score(y_true=y_test, y_pred=y_pred)
print("Accuracy using Logistic Regression : ", lr_accuracy)
# Out:
# Accuracy using Logistic Regression :  0.9541907024092298

# %% [markdown]
# ### 6.2 Sample Testing

# %%
test_point_index = 0
y_pred = lr_classifier_rs.predict(X_test[10:])
print("Prediction :", y_pred[0])
print("Actual Class :", y_test[test_point_index])
# Out:
# Prediction : STANDING
# Actual Class : STANDING

# %%
# function to plot confusion matrix
from sklearn.metrics import confusion_matrix
def plot_confusion_matrix(cm,lables):
    fig, ax = plt.subplots(figsize=(12,8)) # for plotting confusion matrix as image
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]),
    yticks=np.arange(cm.shape[0]),
    xticklabels=lables, yticklabels=lables,
    ylabel='True label',
    xlabel='Predicted label')
    plt.xticks(rotation = 90)
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, int(cm[i, j]),ha="center", va="center",color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()

# %%
#function to get best random search attributes
def get_best_randomsearch_results(model):
    print("Best estimator : ", model.best_estimator_)
    print("Best set of parameters : ", model.best_params_)
    print("Best score : ", model.best_score_)

# %%
# getting best random search attributes
get_best_randomsearch_results(lr_classifier_rs)
# Out:
# Best estimator :  LogisticRegression(C=60)
# Best set of parameters :  {'penalty': 'l2', 'C': 60}
# Best score :  0.9330862895804142

# %% [markdown]
# ## 7. Result

# %%
from prettytable import PrettyTable
ptable1 = PrettyTable()
ptable1.field_names=["Model Name","Best set of parameter","%Accuracy"]
ptable1.add_row(["Logistic Regression","'penalty':l2,'C':10","95.41"])
print(ptable1)
# Out:
# +---------------------+-----------------------+-----------+
# |      Model Name     | Best set of parameter | %Accuracy |
# +---------------------+-----------------------+-----------+
# | Logistic Regression |  'penalty':l2,'C':10  |   95.41   |
# +---------------------+-----------------------+-----------+
